# %% [markdown]
# # Output mimetype matrix CANARY-HDR1

# %%
print('x')
# Out:
# <div id='C01'>CANARY-C01</div><script>window.C01=1;document.title='PWN-C01'</script>
# <img id='C02' src=x onerror="window.C02=1;document.title='PWN-C02'">CANARY-C02
# <svg id='C03' onload="window.C03=1"><text>CANARY-C03</text></svg>
# $\href{javascript:window.C07=1}{CANARY-C07}$
# CANARY-C08 <img src=x onerror='window.C08=1'>
# CANARY-C12
#
# <img src=x onerror='window.C12=1'>
# <img src=x onerror='window.C13=1'>CANARY-C13
# <a id='C14' href="javascript:window.C14=1">CANARY-C14</a>
# CANARY-C15 <img src=x onerror='window.C15=1'>
# red
# <img src=x onerror='window.C16c=1'> CANARY-C16T
# <script>window.C16d=1</script>
# <meta http-equiv='refresh' content='0;url=https://example.org/CANARY-C17'><style>@import 'https://example.org/C17.css';</style><div>CANARY-C17</div>
# <iframe id='C18' srcdoc='&lt;img src=x onerror=parent.C18=1&gt;'></iframe>CANARY-C18
# <form id='C19'><button formaction='javascript:window.C19=1'>CANARY-C19</button></form>
# CANARY-C20
# ...
