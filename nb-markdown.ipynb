# %% [markdown]
# # CANARY-M00 markdown cell start

# %% [markdown]
# <img id='M01' src=x onerror="window.M01=1">CANARY-M01

# %% [markdown]
# <script>window.M02=1</script>CANARY-M02

# %% [markdown]
# <svg onload='window.M03=1'></svg>CANARY-M03

# %% [markdown]
# [CANARY-M04](javascript:window.M04=1)

# %% [markdown]
# CANARY-M05

# %% [markdown]
# <a href='&#106;avascript:window.M06=1'>CANARY-M06</a>

# %% [markdown]
# $$\href{javascript:window.M07=1}{CANARY-M07}$$

# %% [markdown]
# $\unicode{<img src=x onerror=window.M08=1>}$ CANARY-M08

# %% [markdown]
# <div onmouseover='window.M09=1' style='width:9999px;height:9999px'>CANARY-M09</div>

# %% [markdown]
# <iframe src='javascript:window.M10=1'></iframe>CANARY-M10

# %% [markdown]
# <style>*{background:url('https://example.org/M11.png')}</style>CANARY-M11

# %% [markdown]
# ![img](attachment:evil.svg)
#
# CANARY-M12

# %% [markdown]
# ![img](attachment:evil.html)
#
# CANARY-M13

# %% [raw]
# <img src=x onerror='window.R01=1'>CANARY-R01

# %% [raw]
# <script>window.R02=1</script>CANARY-R02

# %% [raw]
# <img src=x onerror='window.R03=1'>CANARY-R03

# %% [markdown]
# CANARY-M14
